# %%
import numpy as np
import pylab
from IPython.display import Image

# %%
RLy_1 = [3.2460093625435875, 3.2336551455210962, 3.2213084821186477, 3.208960488141744, 3.1966023382712483, 3.1842252459928124, 3.171820444019158, 3.1593791651242475, 3.146892623314663, 3.1343519952694545, 3.1217484019855313, 3.109072890571339, 3.0963164161373835, 3.0834698237380582, 3.0705238303255498, 3.0574690066833465, 3.0442957593143225, 3.030994312266691, 3.0175546888905243, 3.0039666935283584, 2.990219893155834, 2.976303599002856, 2.9622068482026505, 2.947918385535959, 2.9334266453608455]

# %%
RLy_2 = [2.4337, 1.9132, 1.7488, 1.6562, 1.5973, 1.5551, 1.5224, 1.4976, 1.4769, 1.4603, 1.4442, 1.4309, 1.4188, 1.4086, 1.3990, 1.3920, 1.3834, 1.3759, 1.3692, 1.3631, 1.3574, 1.3519, 1.3470, 1.3421, 1.3375]

# %%
RLy_3 = [1.8431, 1.6349, 1.5192, 1.4098, 1.3367, 1.3010, 1.2509, 1.2414, 1.2341, 1.2275, 1.2218, 1.2175, 1.2123, 1.2087, 1.2053, 1.2021, 1.1993, 1.1972, 1.1945, 1.1923, 1.1905, 1.1884, 1.1870, 1.1854, 1.1838]

# %%
RW = [6.3055, 5.4266, 4.5595, 3.6435, 2.7861, 2.1374, 1.7119, 1.4284, 1.2178, 1.0510, 0.9220, 0.8170, 0.7395, 0.6723, 0.6164, 0.5752, 0.5408, 0.5072, 0.4795, 0.4661, 0.4407, 0.4234, 0.4194, 0.3948, 0.3833]

# %%
LSTMy = [2.9032, 2.2610, 1.9195, 1.6992, 1.5544, 1.4496, 1.3684, 1.3031, 1.2474, 1.1993, 1.1576, 1.1192, 1.0845, 1.0526, 1.0235, 0.9967, 0.9719, 0.9497, 0.9273, 0.9070, 0.8887, 0.8708, 0.8545, 0.8382, 0.8244]

# %%
from pylab import *
 
t = arange(0.0, 25.0, 1)
plot(t, LSTMy, label = 'LSTM')
plot(t, RLy_1, label = 'RNN_Letter_v1')
plot(t, RLy_2, label = 'RNN_Letter_v2')
plot(t, RLy_3, label = 'RNN_Letter_v3')
plot(t, RW, label = 'RW')

pylab.legend(loc='best')
xlabel('Epoch')
ylabel('Losses')
title('Losses in Epoch = 25')
grid(True)
fig1 = plt.gcf()
fig1.show()

# %%
fig1.savefig('Losses in Epoch = 25', dpi=100)

# %%
x = range(0, len(RNN_FULL))
y = RNN_FULL

# %%
from pylab import * 
t = arange(0.0, len(RNN_FULL), 1)
plot(t, RNN_FULL, label = 'RNN_FULL')
pylab.legend(loc='best')
xlabel('Epoch')
ylabel('Losses')
title('RNN Full in Epoch')
grid(True)
fig2 = plt.gcf()
fig2.show()

# %%
fig2.savefig('RNN Full in Epoch.png', dpi=100)
