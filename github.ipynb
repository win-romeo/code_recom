# %%
import bq_helper 
github_repos = bq_helper.BigQueryHelper(active_project= "bigquery-public-data", 
                                       dataset_name = "github_repos")
github_repos.list_tables()
# Out:
# --------------------------------------------------------------------
# DefaultCredentialsError            Traceback (most recent call last)
# <ipython-input-2-8e5bdcb1c24b> in <module>()
#       1 import bq_helper
#       2 github_repos = bq_helper.BigQueryHelper(active_project= "bigquery-public-data",
# ----> 3                                        dataset_name = "github_repos")
#       4 github_repos.list_tables()
#
# ~/585/src/bq-helper/bq_helper.py in __init__(self, active_project, dataset_name, max_wait_seconds)
#      23         self.dataset_name = dataset_name
#      24         self.max_wait_seconds = max_wait_seconds
# ---> 25         self.client = bigquery.Client()
#      26         self.__dataset_ref = self.client.dataset(self.dataset_name, project=self.project_name)
#      27         self.dataset = None
#
# ~/anaconda3/lib/python3.7/site-packages/google/cloud/bigquery/client.py in __init__(self, project, credentials, _http, location, default_query_job_config)
#     129             location=None, default_query_job_config=None):
#     130         super(Client, self).__init__(
# --> 131             project=project, credentials=credentials, _http=_http)
#     132         self._connection = Connection(self)
#     133         self._location = location
#
# ~/anaconda3/lib/python3.7/site-packages/google/cloud/client.py in __init__(self, project, credentials, _http)
#     213
#     214     def __init__(self, project=None, credentials=None, _http=None):
# --> 215         _ClientProjectMixin.__init__(self, project=project)
#     216         Client.__init__(self, credentials=credentials, _http=_http)
#
# ~/anaconda3/lib/python3.7/site-packages/google/cloud/client.py in __init__(self, project)
#     167
#     168     def __init__(self, project=None):
# --> 169         project = self._determine_default(project)
#     170         if project is None:
#     171             raise EnvironmentError('Project was not passed and could not be '
#
# ~/anaconda3/lib/python3.7/site-packages/google/cloud/client.py in _determine_default(project)
#     180     def _determine_default(project):
#     181         """Helper:  use default project detection."""
# --> 182         return _determine_default_project(project)
#     183
#     184
#
# ~/anaconda3/lib/python3.7/site-packages/google/cloud/_helpers.py in _determine_default_project(project)
#     177     """
#     178     if project is None:
# --> 179         _, project = google.auth.default()
#     180     return project
#     181
#
# ~/anaconda3/lib/python3.7/site-packages/google/auth/_default.py in default(scopes, request)
#     304             return credentials, effective_project_id
#     305
# --> 306     raise exceptions.DefaultCredentialsError(_HELP_MESSAGE)
#
# DefaultCredentialsError: Could not automatically determine credentials. Please set GOOGLE_APPLICATION_CREDENTIALS or explicitly create credentials and re-run the application. For more information, please see https://cloud.google.com/docs/authentication/getting-started
